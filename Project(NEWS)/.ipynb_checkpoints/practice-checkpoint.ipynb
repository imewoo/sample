# %%
import os #파일경로 바탕화면으로 수정
path='C:/Users/user/Desktop'
os.chdir(path)

# %%
############################################################
##########프로젝트 MBN 홈페이지 긁어오는 함수 코드##########
############################################################

import requests
import sys
from bs4 import BeautifulSoup
import json


def MBN_News_Function():
    
    count=0
    result_list=[]
    
    while count<8:
        
        if count==0:
            category_s='politics'
            MBN_url='https://www.mbn.co.kr/news/politics/'
        
        if count==1:
            category_s='economy'
            MBN_url='https://www.mbn.co.kr/news/economy/'

        elif count==2:
            category_s='society'
            MBN_url='https://www.mbn.co.kr/news/society/'

        elif count==3:
            category_s='world'
            MBN_url='https://www.mbn.co.kr/news/world/'

        elif count==4:
            category_s='culture'
            MBN_url='https://www.mbn.co.kr/news/culture/'

        elif count==5:
            category_s='entertain'
            MBN_url='https://www.mbn.co.kr/news/entertain/'        

        elif count==6:
            category_s='sports'
            MBN_url='https://www.mbn.co.kr/news/sports/'

        elif count==7:
            category_s='life'
            MBN_url='https://www.mbn.co.kr/news/life/'


        for i in range(1,2): #페이지번호
            params={
                'page':i,
                'vod':None,
                'category':category_s
            }
            resp=requests.get(MBN_url, params=params)

            resp.encoding='eur-kr'
            soup=BeautifulSoup(resp.text, "lxml")

            MBN_news_list=soup.select('div.list_area > dl.article_list > dt.tit > a')
            MBN_news_list_date=soup.select('div.list_area > dl.article_list > dd.desc > span.date')

            news_list=[]
            for news,date in zip(MBN_news_list, MBN_news_list_date):

                news=news.text.strip() #제목 내 띄어쓰기 제거
                news=news.replace("\'" , " ") #제목 내 따옴표 제거
                news=news.replace("♥" , " ") #제목 내 따옴표 제거
                news=news.replace("[포토]"," ") #제목 내 [포토] 제거

                date=date.text[0:10].replace("-","")

                if date == '20200805': #날짜 수정하면 됨
                    news_list.append(news)

            result_list.append(news_list)

        count+=1

    return result_list

# %%
############################################################
#########프로젝트 MBN 메모장으로 꺼내오는 함수 코드#########
############################################################

# a1, 2, 3, 4 -> 정치
# b1, 2, 3, 4 -> 경제
# c1, 2, 3, 4 -> 사회
# d1, 2, 3, 4 -> 국제
# e1, 2, 3, 4 -> 생활&문화, 문화 + mbn생활건강 +ytn전국,과학
# f1, 2, 3, 4 -> 연예
# g1, 2, 3, 4 -> 스포츠



#f=[]
#i=1
#f[1]=a4, f[2]=b4, f[3]=c4


# for title in title_list:
#     f[i]=open('{}4.txt'.format(title),'w',-1,"utf-8")
#     i+=1


title_list=['a','b','c','d','e','f','g','j'] #나중에 j를 e로 바꿔서 추가해야함!

f_list=[]
for title in title_list:
    f=open('{}4.txt'.format(title),'w',-1,"utf-8")    
    f_list.append(f)

    
To_Memo=MBN_News_Function()   # 2중리스트로 옴. [[1,2,3...] , [1,2,3...] , [1,2,3...]]


for i, f in zip(To_Memo,f_list):
    for j in i:
        f.write(j)
    f.close()

To_Memo
# Out:
# [['"부동산 올라도 상관없다" 김진애에…김근식 "오만하고 무책임"',
#   '[레이더P] 이상헌 의원, `게임 등급분류 선진화법` 발의',
#   '통합당 토론회 "1919 건국론은 대한민국 부정"…역사 논쟁 제기',
#   '[레이더P] 청년층 지지율 하락에…文 "청년 주거, 일자리 해결 부족"',
#   '정경두 "극초음속 미사일 개발"…공개적으로 첫 언급',
#   '김용판 의원, 해외진출한 기업 국내 복귀 지원 강화하는 법안 발의',
#   '장애인단체 "이광재  절름발이  발언, 명백한 장애인 혐오 표현"',
#   '류호정, 원피스 복장에 일부 누리꾼 막말…진중권 "국회복 따로 있나"',
#   '시민단체,  몸싸움 압수수색  논란 한동훈·윤석열 감찰 법무부에 진정',
#   '문대통령 "일자리·주거…지금 청년들 문제, 예전보다 복잡"',
#   '조해진, `독재` 발언한 윤석열에 "인내심 한계 온 것"',
#   '트럼프, 韓 코로나 통계에 딴지…사망자 적단 말에 "그건 모를 일"',
#   '"세금만 열심히 내라" 김진애 해명 "통합당 의원들에 한 말"',
#   '[레이더P] 홍준표 "25년 정치생활 중 이렇게 무도한 여당, 무기력한 야당 본 일 없어"',
#   '홍준표 "25년 정치 생활 중 이렇게 무도한 여당 본 적 없어"',
#   '하태경 "文 정부, 과학계까지 촛불과 적폐로 양분해 억압"',
#   '원희룡 "법의 지배가 무섭다는 발상? 與 지은 죄 많은가"',
#   '이제는 `이대만`?…지지율 뚝 이낙연의 난제',
#   '류호정 원피스 차림에 "옵빠 한번 외쳐라"…진중권 "미친 XX들"',
#   '홍준표 "중구난방 박수부대 국회…암담하다"'],
#  ['여름휴가 `집콕` 대세에 카드사 신상카드 바뀐다',
#   '`카카오프렌즈` 이사간다…카카오IX 사업구조 개편',
#   '씨티케이코스메틱스, 이베이코리아와 이커머스 사업 활성화 위한 MOU',
#   '주택금융공사, 도심 속 코스모스 산책로 조성',
#   '경제위기 때 취업한 세대, 10년동안 임금 적게 받아',
#   '조폐공사 조용만 사장, 플라워버킷 챌린지 동참',
#   '코스피, `동학개미` 매수에 1%대 상승 마감…2310선 돌파',
#   '5G 속도 LTE 보다 4배 빨라졌지만…국민 눈높이에 `미달`',
#   '요린이도 근사한 한 끼 만들게 하는 `밀키트` 잘 팔리네',
#   '지평 이랑이랑, 출시 2주만에 5만병 판매',
#   '코스닥, 11.93p(1.43%) 오른 847.28 마감',
#   '코스피, 31.89p(1.40%) 오른 2311.86 마감',
#   '셀트리온 빅 피쳐 나왔다…2023년 `송도 3공장` 착공→셀트리온 타운 조성',
#   '일주일 남은 최후통첩…아시아나항공 M&A 안갯속',
#   '애플, `시총 2조달러` 눈앞…"국내증시 시총 1.2배 넘겨"',
#   '엘랑코에 새 둥지 튼 바이엘 세레스토, 반려동물 영양제 출시한다',
#   '민주당,  뉴딜 펀드  띄우기…"국채 수익률+α 보장"',
#   '고강도 규제 무색…4년 간 서울 재건축 1순위 청약 마감률 100%',
#   '매일유업, 취약계층 후원금 7800만원 전달',
#   'NH투자증권 100세시대 연구소, `2020 대한민국 농촌경제보고서` 발간'],
#  ['천안시청 "관내 114번째 확진자 발생…아산시 탕정면 거주 60대"',
#   '경기도 고양서 관내 89번 확진자 발생…주교동 거주',
#   '임진강 필승교 수위 사실상 역대 최고치 경신',
#   'BBQ,  써프라이드  상표명 못쓴다…저작권 소송 패소 확정',
#   '검찰에 위임됐던 국가소송·행정소송…12월부터는 법무부가 맡는다',
#   '구멍난 하늘과 폭우, 긴 장마 그리고 반지하 사람들',
#   '용인서 20대 남성 코로나19 확진…무증상 해외입국자',
#   '[인사] 서민금융진흥원',
#   '소양강댐 방류로 한강 수위 1∼2ｍ 증가…16시간 뒤 서울 도달',
#   '올 여름 덥다던 기상청 예보 완전히 빗나간 이유는',
#   '[MBN 프레스룸] 이동재 전 채널A 기자 기소…한동훈 공모 적시 안 해',
#   'BBQ,  써프라이드  상표명 못쓴다…저작권 소송 최종 패소',
#   '전공의 파업 예고에 주요 대학병원 "진료 차질 없게 대비"',
#   '부산서 이면도로 빠져나온 승용차가 시내버스 들이받아…승객 2명 경상',
#   '[속보] 소양강댐 3년 만에 수문 개방…초당 3천t 방류 시작',
#   '[속보] 소양강댐 3년 만인 오후 3시 수문 개방…초당 3000t 방류 시작',
#   '임진강 최북단 필승교 수위 사실상 역대 최고치 넘어',
#   '언택트금융범죄 급증…검거율은 `뚝`',
#   '수해지역 장티푸스·이질 감염 주의',
#   '울산시의회 본회의장 천장 갑자기 무너져 `아찔`'],
#  ['베이루트서 초대형 폭발사고…4000여명 사상',
#   '日방위상 "한국 양해 왜 필요한가"…적기지공격능력 보유 추진 논란',
#   '가글액이 코로나 억제에 효과적?…일본 연구결과 발표에 사재기 조짐',
#   '레바논 베이루트 폭발 참사 사망자 100명 이상…부상자 4천 명 넘어',
#   '중국 코로나19 위중 환자 90% 완치 후에도 폐 기능 손상',
#   '아프간서 IS 습격으로 수감된 전투원 270명 탈옥',
#   '베이루트 폭발참사 사망자 100명 넘어…부상자 4000명',
#   '아프가니스탄 교도소 습격 틈타 죄수 270명 탈출…대부분 IS 조직원 출신',
#   '"사면초가 레바논 무릎꿇린 대재앙"…내전·재정파탄·코로나로 이미 휘청',
#   '[속보] "베이루트 폭발참사 사망자 100명 넘어서"',
#   '중국 하얼빈서 식품회사 창고 건물 붕괴…9명 사망',
#   '"왜 마스크 안 써" 뜨거운 커피 얼굴에 끼얹은 여성',
#   '중국 보란듯…美보건부 장관, 대만에 첫 고위급 방문',
#   '레바논 폭발사고, 16년 전 北룡천역 참사와 판박이',
#   '레바논 `2차 폭발` 키운건 질산암모늄…1차 폭발 원인은?',
#   '트럼프 "끔찍한 공격"이라 했지만…`레바논 폭발` 둘러싼 미스터리',
#   '베이루트 폭발 현장서 1.6km떨어진 총리관저도 박살...규모 3.3 인공지진',
#   '"핵폭발 같았다"…레바논 대형참사 사망 78명·부상 4천명',
#   '낮엔 식당 운영하고 밤엔 땅굴 파…중국 영화 같은 도굴 사건',
#   '홍콩 치안 위기…대낮에 전철역서 흉기 들고 롤렉스시계 강탈'],
#  ['밴드 설, 새 싱글 ‘돈트 세이 노’ 발매',
#   '산들, 새 앨범 ‘생각집 EP.1’ 발매',
#   '한승우, 첫 솔로 앨범 ‘페임’ 3종 이미지 티저 공개',
#   '인터파크, 태국관광청과 얼리버드 프로모션 진행',
#   '한국관광공사, 구미주 시장 겨냥 ‘온택트 마케팅’ 시동',
#   '카카오M, 드라마 제작사 바람픽쳐스 인수',
#   ' 보이스트롯  박세욱 선우, 묘한 핑크빛 기류…1호 커플 탄생?',
#   '영화수입배급사협회, 국내 OTT 서비스 중단',
#   'MBN 간판 예능  우리 다시 사랑할 수 있을까  시즌3,  김용건-황신혜 등 역대급 캐스팅으로 컴백!',
#   '방탄소년단, 미국 MTV서 신곡 첫 무대',
#   '영화 `반도`, 캐나다·북유럽 개봉',
#   '파도처럼 강인한 그대를 위하여!…코로나19 방역 의료진 위한 전시 열린다',
#   '방탄소년단, 미국 비디오뮤직어워즈서 신곡  다이너마이트  첫 무대',
#   ' 출사표  나나 박성훈 연애 시작 후 첫 위기?',
#   '세종문화회관, 국내 공연장 최초 비대면 검표 도입'],
#  ['김희재 DJ 발탁, `이수영의 12시에 만납시다` 스페셜 DJ 활약 예고',
#   '`한밤` 이영지 "1일 1훠궈...훠궈에 들인 돈이 어마어마"',
#   '신민아 김우빈 1억원 기부...누리꾼 "마음씨도 예쁜 선행커플"',
#   '김호중 측 "前여친 父 허위사실 유포 명예훼손 혐의로 6일 고소"[공식]',
#   '입짧은햇님, 뒷광고 논란 언급 "저는 쫄보라 못해"',
#   '권민아 근황 “많은 것 준비 중, 나중에 깜짝 놀랄 것”',
#   '`한밤` 이규형, 연락처 있는 女연예인과 연애운無 타로점에 "휴대폰 갖다 버려야"',
#   '`세븐 ` 이다해, 절친 박시연과 `여신美`',
#   '수지, 떡볶이 앞에서 함박웃음..."풀은 패스"',
#   '`눈누난나` 제시, 김숙 수준급 댄스 실력에...`언니쓰`',
#   '돈스파이크, 30kg 감량 비법은? "개업 다이어트 보증합니다"',
#   '서현, 13년 전 사진 공개...`데뷔부터 완성형 미모`',
#   '송혜교 "인생에서 가장 중요한 감정은 유대감과 진심"(화보)',
#   '`찐한친구` 하하, 유재석 강제 소환 "재석형도 돈이 최고래"',
#   '‘절필’ 임성한 작가, 내년 상반기 드라마 컴백설…TV조선 “사실무근”',
#   '`오래 살고 볼일` 한혜진 MC 발탁…10월 첫방송 예정 [공식]',
#   '(여자)아이들, 신곡  덤디덤디  41개국 아이튠즈 1위',
#   '`박성광 ` 이솔이, 결혼식 앞두고 심란?..."마음도 우기"',
#   '정가은 "일할 수 있다는 감사함, 어릴 땐 몰라...철드는 중"',
#   ' 정오의 희망곡  엄정화 "진짜 환불 받을 것 같은 멤버? 이효리"'],
#  ['삼성 새 외국인 타자 팔카, 오늘 한국 도착…마당 있는 펜션서 자가격리',
#   '김광현 소속 팀 세인트루이스 포수 몰리나, 코로나19 확진',
#   '2020년 KBO리그는 바야흐로 `로하스 시대`…타격 6개 부문 1위',
#   '이임생 전 수원 감독,  강등 위기  인천 새 감독 낙점',
#   '풀럼, 브렌트퍼드 꺾고 1시즌만에 EPL 복귀',
#   '시즌 세번째 등판 앞둔 류현진, 머리 깎고 심기일전'],
#  ['파주 임진강 비룡대교 일대 홍수주의보 발령…"인근 주민 유의해야"',
#   '임진강 필승교 올해 최고 수위… 접경지역 위기대응 관심단계  경보',
#   '[속보] 한강홍수통제소, 임진강 필승교  위기 경보 …수위 7.5m넘어',
#   '[속보] 소양강댐 제한수위 초과…오후 3시 3년만에 수문 개방',
#   '전북 전주·정읍 등 5곳 호우주의보…"우산 써도 옷 젖는다"',
#   '워터파크⋅해수욕장 방역수칙 위반 12건 적발',
#   '해양환경공단, 장마에 바다로 떠내려온 쓰레기 382t 수거',
#   '브라질 입국자 20대, 충남 당진에서 자가격리 중 코로나19 확진',
#   '한강 잠수교 전면통제 나흘째 계속',
#   '가평 단수 지역 11시간 만에 수돗물 공급 재개',
#   '고수·바질 등에서 잔류 농약 검출…식약처, 허브류 6건 폐기 조치',
#   '오늘의 날씨, 수도권 시간당 50∼100㎜ 폭우…낮 최고 26~34도',
#   '2020년 8월 5일 오늘의 운세']]

# %%
f_list
# Out:
# [<_io.TextIOWrapper name='a4.txt' mode='w' encoding='utf-8'>,
#  <_io.TextIOWrapper name='b4.txt' mode='w' encoding='utf-8'>,
#  <_io.TextIOWrapper name='c4.txt' mode='w' encoding='utf-8'>,
#  <_io.TextIOWrapper name='d4.txt' mode='w' encoding='utf-8'>,
#  <_io.TextIOWrapper name='e4.txt' mode='w' encoding='utf-8'>,
#  <_io.TextIOWrapper name='f4.txt' mode='w' encoding='utf-8'>,
#  <_io.TextIOWrapper name='g4.txt' mode='w' encoding='utf-8'>,
#  <_io.TextIOWrapper name='j4.txt' mode='w' encoding='utf-8'>]
